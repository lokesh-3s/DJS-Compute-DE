# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np
plt.style.use('ggplot')
df=pd.read_csv(r"D:\DE\breast_cancer_survival - breast_cancer_survival_.csv.csv")
df
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 334 non-null    int64
#  1   Gender              334 non-null    object
#  2   Protein1            334 non-null    float64
#  3   Protein2            334 non-null    float64
#  4   Protein3            334 non-null    float64
#  5   Protein4            334 non-null    float64
#  6   Tumour_Stage        334 non-null    object
#  7   Histology           334 non-null    object
#  8   ER status           334 non-null    object
#  9   PR status           334 non-null    object
#  10  HER2 status         334 non-null    object
#  11  Surgery_type        334 non-null    object
#  12  Date_of_Surgery     334 non-null    object
#  13  Date_of_Last_Visit  317 non-null    object
#  14  Patient_Status      321 non-null    object
# ...

# %%
df.duplicated().sum() #no duplicate entries found
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Protein1               0
# Protein2               0
# Protein3               0
# Protein4               0
# Tumour_Stage           0
# Histology              0
# ER status              0
# PR status              0
# HER2 status            0
# Surgery_type           0
# Date_of_Surgery        0
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
df=df.dropna().reset_index(drop=True).copy()
df #dropping entries with null values
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 312   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 313   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 314   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 315   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 316   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
df['Date_of_Last_Visit']
# Out:
# 0      26-Aug-18
# 1      25-Jan-19
# 2      08-Apr-20
# 3      28-Jul-20
# 4      05-Jan-19
#          ...
# 312    27-Mar-20
# 313    23-Apr-19
# 314    11-Oct-19
# 315    05-Dec-18
# 316    10-Aug-19
# Name: Date_of_Last_Visit, Length: 317, dtype: object

# %%
df.describe()
# Out:
#               Age    Protein1    Protein2    Protein3    Protein4
# count  317.000000  317.000000  317.000000  317.000000  317.000000
# mean    58.725552   -0.027232    0.949557   -0.095104    0.006713
# std     12.827374    0.543858    0.906153    0.589027    0.625965
# min     29.000000   -2.144600   -0.978730   -1.627400   -2.025500
# 25%     49.000000   -0.350600    0.368840   -0.531360   -0.382240
# 50%     58.000000    0.005649    0.997130   -0.193040    0.038522
# 75%     67.000000    0.336260    1.612000    0.251210    0.436250
# max     90.000000    1.593600    3.402200    2.193400    1.629900

# %%
df.boxplot()
plt.show() #Outliers detected

# %%
def remove_outliers_iqr(df, columns):

    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

columns_to_check = ['Age','Protein1','Protein2','Protein3','Protein4']
df = remove_outliers_iqr(df, columns_to_check)

# %%
df.boxplot()
plt.show() #Outlier Removed

# %%
df.describe() #change in values like max and min show outlier removal
# Out:
#               Age    Protein1    Protein2    Protein3    Protein4
# count  299.000000  299.000000  299.000000  299.000000  299.000000
# mean    58.678930   -0.003626    0.985858   -0.125889    0.052736
# std     12.849304    0.485770    0.898234    0.551525    0.567935
# min     29.000000   -1.379100   -0.978730   -1.627400   -1.451600
# 25%     49.000000   -0.337455    0.436810   -0.537305   -0.350700
# 50%     58.000000    0.006610    1.071900   -0.204260    0.048602
# 75%     67.500000    0.337825    1.641200    0.231050    0.462065
# max     89.000000    1.090200    3.402200    1.337900    1.629900

# %%
df.nunique()
# Out:
# Age                    56
# Gender                  2
# Protein1              298
# Protein2              299
# Protein3              299
# Protein4              298
# Tumour_Stage            3
# Histology               3
# ER status               1
# PR status               1
# HER2 status             2
# Surgery_type            4
# Date_of_Surgery       172
# Date_of_Last_Visit    268
# Patient_Status          2
# dtype: int64

# %%
df['Tumour_Stage'].unique()
# Out:
# array(['II', 'I', 'III'], dtype=object)

# %%
df['Histology'].unique()
# Out:
# array(['Infiltrating Ductal Carcinoma', 'Infiltrating Lobular Carcinoma',
#        'Mucinous Carcinoma'], dtype=object)

# %%
df['Surgery_type'].unique()
# Out:
# array(['Other', 'Lumpectomy', 'Modified Radical Mastectomy',
#        'Simple Mastectomy'], dtype=object)

# %%
ax=df.groupby("Gender")['Age'].count().plot(kind='bar')
ax.set_ylabel('Frequency')
plt.show()

# %%
df['Age'].plot(kind='hist')
plt.show()
#with describe and histogram we can conclude breast cancer to happen maximum in people of age around 59 and can happen to people with age as low as 19 and as high as 90

# %%
sns.pairplot(df,vars=['Protein1','Protein2','Protein3','Protein4'],hue='Age')
plt.show() #shows that age and proteins as well as proteins are not inter dependent

# %%
bx=df.groupby("Patient_Status")["Age"].count().plot(kind='bar')
bx.set_ylabel('No of Patients')
plt.show()

# %%
dfp=df['Tumour_Stage'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Tumour_Stage'].value_counts()
# Out:
# Tumour_Stage
# II     167
# III     72
# I       60
# Name: count, dtype: int64

# %%
df.query('Tumour_Stage=="II"')['Protein1'].plot()
plt.show()
